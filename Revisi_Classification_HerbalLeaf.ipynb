# %%
import os
import zipfile

# %%
# Ekstrak dataset
local_zip = "C:/Users/prithaaulliah/dataset.zip"
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall("C:/Users/prithaaulliah")
zip_ref.close()

# %%
base_dir = "C:/Users/prithaaulliah/dataset_split"
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')
classes = ["Sirih","Seledri","Pepaya","Pandan","Nangka","Lidah buaya","Kemangi","Jeruk Nipis","Jambu biji","Belimbing Wuluh"]

sirih_train_path = os.path.join(train_dir, 'Sirih')
seledri_train_path = os.path.join(train_dir, 'Seledri')
pepaya_train_path = os.path.join(train_dir, 'Pepaya')
pandan_train_path = os.path.join(train_dir, 'Pandan')
nangka_train_path = os.path.join(train_dir, 'Nangka')
lidahbuaya_train_path = os.path.join(train_dir, 'Lidah buaya')
kemangi_train_path = os.path.join(train_dir, 'Kemangi')
jeruk_train_path = os.path.join(train_dir, 'Jeruk Nipis')
jambubiji_train_path = os.path.join(train_dir, 'Jambu biji')
belimbingwuluh_train_path = os.path.join(train_dir, 'Belimbing Wuluh')

sirih_val_path = os.path.join(val_dir, 'Sirih')
seledri_val_path = os.path.join(val_dir, 'Seledri')
pepaya_val_path = os.path.join(val_dir, 'Pepaya')
pandan_val_path = os.path.join(val_dir, 'Pandan')
nangka_val_path = os.path.join(val_dir, 'Nangka')
lidahbuaya_val_path = os.path.join(val_dir, 'Lidah buaya')
kemangi_val_path = os.path.join(val_dir, 'Kemangi')
jeruk_val_path = os.path.join(val_dir, 'Jeruk Nipis')
jambubiji_val_path = os.path.join(val_dir, 'Jambu biji')
belimbingwuluh_val_path = os.path.join(val_dir, 'Belimbing Wuluh')

len_sirih_train = len(os.listdir(sirih_train_path))
len_seledri_train = len(os.listdir(seledri_train_path))
len_pepaya_train = len(os.listdir(pepaya_train_path))
len_pandan_train = len(os.listdir(pandan_train_path))
len_nangka_train = len(os.listdir(nangka_train_path))
len_lidahbuaya_train = len(os.listdir(lidahbuaya_train_path))
len_kemangi_train = len(os.listdir(kemangi_train_path))
len_jeruk_train = len(os.listdir(jeruk_train_path))
len_jambubiji_train = len(os.listdir(jambubiji_train_path))
len_belimbingwuluh_train = len(os.listdir(belimbingwuluh_train_path))

len_sirih_val = len(os.listdir(sirih_val_path))
len_seledri_val = len(os.listdir(seledri_val_path))
len_pepaya_val = len(os.listdir(pepaya_val_path))
len_pandan_val = len(os.listdir(pandan_val_path))
len_nangka_val = len(os.listdir(nangka_val_path))
len_lidahbuaya_val = len(os.listdir(lidahbuaya_val_path))
len_kemangi_val = len(os.listdir(kemangi_val_path))
len_jeruk_val = len(os.listdir(jeruk_val_path))
len_jambubiji_val = len(os.listdir(jambubiji_val_path))
len_belimbingwuluh_val = len(os.listdir(belimbingwuluh_val_path))

print("Panjang train:", str(len_sirih_train + len_seledri_train + len_pepaya_train + len_pandan_train + len_nangka_train + len_lidahbuaya_train + len_kemangi_train + len_jeruk_train + len_jambubiji_train + len_belimbingwuluh_train))
print("Panjang validation:", str(len_sirih_val + len_seledri_val + len_pepaya_val + len_pandan_val + len_nangka_val + len_lidahbuaya_val + len_kemangi_val + len_jeruk_val + len_jambubiji_val + len_belimbingwuluh_val))

print('''\n==== Jumlah data train ====
Panjang data train Sirih: {}
Panjang data train Peledri: {}
Panjang data train Pepaya: {}
Panjang data train Pandan: {}
Panjang data train Nangka: {}
Panjang data train Lidah Buaya: {}
Panjang data train Kemangi: {}
Panjang data train Jeruk Nipis: {}
Panjang data train Jambu Biji: {}
Panjang data train Belimbing Wuluh: {}
'''.format(len_sirih_train, len_seledri_train, len_pepaya_train, len_pandan_train, len_nangka_train, len_lidahbuaya_train, len_kemangi_train, len_jeruk_train, len_jambubiji_train, len_belimbingwuluh_train))

print('''\n==== Jumlah data validation ====
Panjang data validation Sirih: {}
Panjang data validation Peledri: {}
Panjang data validation Pepaya: {}
Panjang data validation Pandan: {}
Panjang data validation Nangka: {}
Panjang data validation Lidah Buaya: {}
Panjang data validation Kemangi: {}
Panjang data validation Jeruk Nipis: {}
Panjang data validation Jambu Biji: {}
Panjang data validation Belimbing Wuluh: {}
'''.format(len_sirih_val, len_seledri_val, len_pepaya_val, len_pandan_val, len_nangka_val, len_lidahbuaya_val, len_kemangi_val, len_jeruk_val, len_jambubiji_val, len_belimbingwuluh_val))
# Out:
# Panjang train: 2450
# Panjang validation: 700
#
# ==== Jumlah data train ====
# Panjang data train Sirih: 245
# Panjang data train Peledri: 245
# Panjang data train Pepaya: 245
# Panjang data train Pandan: 245
# Panjang data train Nangka: 245
# Panjang data train Lidah Buaya: 245
# Panjang data train Kemangi: 245
# Panjang data train Jeruk Nipis: 245
# Panjang data train Jambu Biji: 245
# Panjang data train Belimbing Wuluh: 245
#
#
# ==== Jumlah data validation ====
# Panjang data validation Sirih: 70
# Panjang data validation Peledri: 70
# Panjang data validation Pepaya: 70
# Panjang data validation Pandan: 70
# Panjang data validation Nangka: 70
# Panjang data validation Lidah Buaya: 70
# Panjang data validation Kemangi: 70
# Panjang data validation Jeruk Nipis: 70
# Panjang data validation Jambu Biji: 70
# Panjang data validation Belimbing Wuluh: 70

# %%
train_sirih_fnames = os.listdir(sirih_train_path)
train_seledri_fnames = os.listdir(seledri_train_path)
train_pepaya_fnames = os.listdir(pepaya_train_path)
train_pandan_fnames = os.listdir(pandan_train_path)
train_nangka_fnames = os.listdir(nangka_train_path)
train_lidahbuaya_fnames = os.listdir(lidahbuaya_train_path)
train_kemangi_fnames = os.listdir(kemangi_train_path)
train_jeruk_fnames = os.listdir(jeruk_train_path)
train_jambubiji_fnames = os.listdir(jambubiji_train_path)
train_belimbingwuluh_fnames = os.listdir(belimbingwuluh_train_path)

print(train_sirih_fnames[:10])
print(train_seledri_fnames[:10])
print(train_pepaya_fnames[:10])
print(train_pandan_fnames[:10])
print(train_nangka_fnames[:10])
print(train_lidahbuaya_fnames[:10])
print(train_kemangi_fnames[:10])
print(train_jeruk_fnames[:10])
print(train_jambubiji_fnames[:10])
print(train_belimbingwuluh_fnames[:10])
# Out:
# ['Sirih001.jpg', 'Sirih002.jpg', 'Sirih003.jpg', 'Sirih004.jpg', 'Sirih005.jpg', 'Sirih006.jpg', 'Sirih008.jpg', 'Sirih011.jpg', 'Sirih012.jpg', 'Sirih014.jpg']
# ['Seledri001.jpg', 'Seledri002.jpg', 'Seledri003.jpg', 'Seledri004.jpg', 'Seledri005.jpg', 'Seledri006.jpg', 'Seledri008.jpg', 'Seledri011.jpg', 'Seledri012.jpg', 'Seledri014.jpg']
# ['Pepaya001.jpg', 'Pepaya002.jpg', 'Pepaya003.jpg', 'Pepaya004.jpg', 'Pepaya005.jpg', 'Pepaya006.jpg', 'Pepaya008.jpg', 'Pepaya011.jpg', 'Pepaya012.jpg', 'Pepaya014.jpg']
# ['Pandan001.jpg', 'Pandan002.jpg', 'Pandan003.jpg', 'Pandan004.jpg', 'Pandan005.jpg', 'Pandan006.jpg', 'Pandan008.jpg', 'Pandan011.jpg', 'Pandan012.jpg', 'Pandan014.jpg']
# ['Nangka001.jpg', 'Nangka002.jpg', 'Nangka003.jpg', 'Nangka004.jpg', 'Nangka005.jpg', 'Nangka006.jpg', 'Nangka008.jpg', 'Nangka011.jpg', 'Nangka012.jpg', 'Nangka014.jpg']
# ['Lidah Buaya001.jpg', 'Lidah Buaya002.jpg', 'Lidah Buaya003.jpg', 'Lidah Buaya004.jpg', 'Lidah Buaya005.jpg', 'Lidah Buaya006.jpg', 'Lidah Buaya008.jpg', 'Lidah Buaya011.jpg', 'Lidah Buaya012.jpg', 'Lidah Buaya014.jpg']
# ['Kemangi001.jpg', 'Kemangi002.jpg', 'Kemangi003.jpg', 'Kemangi004.jpg', 'Kemangi005.jpg', 'Kemangi006.jpg', 'Kemangi008.jpg', 'Kemangi011.jpg', 'Kemangi012.jpg', 'Kemangi014.jpg']
# ['Jeruk Nipis001.jpg', 'Jeruk Nipis002.jpg', 'Jeruk Nipis003.jpg', 'Jeruk Nipis004.jpg', 'Jeruk Nipis005.jpg', 'Jeruk Nipis006.jpg', 'Jeruk Nipis008.jpg', 'Jeruk Nipis011.jpg', 'Jeruk Nipis012.jpg', 'Jeruk Nipis014.jpg']
# ['Jambu Biji001.jpg', 'Jambu Biji002.jpg', 'Jambu Biji003.jpg', 'Jambu Biji004.jpg', 'Jambu Biji005.jpg', 'Jambu Biji006.jpg', 'Jambu Biji008.jpg', 'Jambu Biji011.jpg', 'Jambu Biji012.jpg', 'Jambu Biji014.jpg']
# ['Belimbing Wuluh001.jpg', 'Belimbing Wuluh002.jpg', 'Belimbing Wuluh003.jpg', 'Belimbing Wuluh004.jpg', 'Belimbing Wuluh005.jpg', 'Belimbing Wuluh006.jpg', 'Belimbing Wuluh008.jpg', 'Belimbing Wuluh011.jpg', 'Belimbing Wuluh012.jpg', 'Belimbing Wuluh014.jpg']

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

nrows = 10
ncols = 8

pic_index = 0

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale = 1./255,
    shear_range = 0.3,
    zoom_range = 0.3,
    rotation_range = 30,
    horizontal_flip = True,
    vertical_flip = True,
    fill_mode = 'nearest',
)
validation_datagen = ImageDataGenerator(
    rescale = 1./255,
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (150,150),
    batch_size = 16,
    class_mode = 'categorical',
    shuffle=True,
)

validation_generator = validation_datagen.flow_from_directory(
    val_dir,
    target_size = (150,150),
    batch_size = 16,
    class_mode = 'categorical',
    shuffle = False,
)

test_datagen = ImageDataGenerator(
    rescale = 1./255,
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size = (150,150),
    batch_size = 16,
    class_mode = 'categorical',
    shuffle = False,
)
# Out:
# Found 2450 images belonging to 10 classes.
# Found 700 images belonging to 10 classes.
# Found 350 images belonging to 10 classes.

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout

# %%
image_size=[150,150]
vgg=VGG16(input_shape=image_size+[3], weights='imagenet', include_top=False)
vgg.output
# Out:
# <KerasTensor: shape=(None, 4, 4, 512) dtype=float32 (created by layer 'block5_pool')>

# %%
x=Flatten()(vgg.output)
x=Dense(512, activation='relu')(x)
prediction=Dense(10,activation='softmax')(x)

# %%
model=Model(inputs=vgg.input, outputs=prediction)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dense_2 (Dense)             (None, 512)               4194816
#
#  dense_3 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 18,914,634
# Trainable params: 18,914,634
# Non-trainable params: 0
# _________________________________________________________________

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs = {}):
    if(logs.get('accuracy') > 0.99):
      print('\nYour model accuration has been reached: 99%')
      self.model.stop_training = True

callbacks = myCallback()

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=tf.optimizers.SGD(learning_rate=1e-4, momentum=0.9),
              metrics=['accuracy'])

# %%
history = model.fit(
      train_generator,
      steps_per_epoch=20,
      epochs=100,
      validation_data=validation_generator,
      validation_steps=10,
      verbose=1,
      callbacks = [callbacks],
)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 17s 807ms/step - loss: 2.2148 - accuracy: 0.1969 - val_loss: 1.5225 - val_accuracy: 0.6313
# Epoch 2/100
# 20/20 [==============================] - 14s 725ms/step - loss: 1.8094 - accuracy: 0.4281 - val_loss: 1.7944 - val_accuracy: 0.3250
# Epoch 3/100
# 20/20 [==============================] - 10s 502ms/step - loss: 1.4078 - accuracy: 0.5000 - val_loss: 0.9971 - val_accuracy: 0.7625
# Epoch 4/100
# 20/20 [==============================] - 15s 752ms/step - loss: 1.0086 - accuracy: 0.6469 - val_loss: 0.6300 - val_accuracy: 0.8438
# Epoch 5/100
# 20/20 [==============================] - 15s 777ms/step - loss: 0.8884 - accuracy: 0.6844 - val_loss: 0.5541 - val_accuracy: 0.8438
# Epoch 6/100
# 20/20 [==============================] - 15s 763ms/step - loss: 0.7259 - accuracy: 0.7469 - val_loss: 0.8662 - val_accuracy: 0.6875
# Epoch 7/100
# 20/20 [==============================] - 14s 713ms/step - loss: 0.6623 - accuracy: 0.7812 - val_loss: 0.6660 - val_accuracy: 0.7812
# Epoch 8/100
# 20/20 [==============================] - 15s 774ms/step - loss: 0.5284 - accuracy: 0.8188 - val_loss: 0.6583 - val_accuracy: 0.7750
# Epoch 9/100
# 20/20 [==============================] - 16s 780ms/step - loss: 0.5908 - accuracy: 0.7844 - val_loss: 0.6085 - val_accuracy: 0.8188
# Epoch 10/100
# 20/20 [==============================] - 15s 756ms/step - loss: 0.5682 - accuracy: 0.8031 - val_loss: 0.3436 - val_accuracy: 0.8938
# Epoch 11/100
# 20/20 [==============================] - 15s 774ms/step - loss: 0.5163 - accuracy: 0.8156 - val_loss: 0.6341 - val_accuracy: 0.7937
# Epoch 12/100
# 20/20 [==============================] - 15s 777ms/step - loss: 0.5117 - accuracy: 0.8344 - val_loss: 0.5402 - val_accuracy: 0.8250
# Epoch 13/100
# 20/20 [==============================] - 15s 771ms/step - loss: 0.4991 - accuracy: 0.8250 - val_loss: 0.3229 - val_accuracy: 0.8813
# Epoch 14/100
# 20/20 [==============================] - 16s 785ms/step - loss: 0.4093 - accuracy: 0.8406 - val_loss: 0.3080 - val_accuracy: 0.8813
# Epoch 15/100
# 20/20 [==============================] - 15s 740ms/step - loss: 0.4521 - accuracy: 0.8531 - val_loss: 0.2296 - val_accuracy: 0.9187
# Epoch 16/100
# 20/20 [==============================] - 15s 764ms/step - loss: 0.2642 - accuracy: 0.9031 - val_loss: 0.2796 - val_accuracy: 0.9062
# Epoch 17/100
# 20/20 [==============================] - 14s 699ms/step - loss: 0.2767 - accuracy: 0.9094 - val_loss: 0.2711 - val_accuracy: 0.9062
# Epoch 18/100
# 20/20 [==============================] - 16s 802ms/step - loss: 0.3808 - accuracy: 0.8625 - val_loss: 1.5546 - val_accuracy: 0.5500
# Epoch 19/100
# 20/20 [==============================] - 16s 800ms/step - loss: 0.4586 - accuracy: 0.8281 - val_loss: 0.2676 - val_accuracy: 0.9000
# Epoch 20/100
# 20/20 [==============================] - 16s 780ms/step - loss: 0.2301 - accuracy: 0.9219 - val_loss: 0.5833 - val_accuracy: 0.7812
# Epoch 21/100
# 20/20 [==============================] - 16s 780ms/step - loss: 0.3892 - accuracy: 0.8687 - val_loss: 0.2864 - val_accuracy: 0.9125
# Epoch 22/100
# 20/20 [==============================] - 15s 773ms/step - loss: 0.2310 - accuracy: 0.9250 - val_loss: 0.2054 - val_accuracy: 0.9438
# Epoch 23/100
# 20/20 [==============================] - 15s 762ms/step - loss: 0.2279 - accuracy: 0.9125 - val_loss: 0.1663 - val_accuracy: 0.9500
# Epoch 24/100
# 20/20 [==============================] - 15s 746ms/step - loss: 0.2893 - accuracy: 0.8906 - val_loss: 0.8906 - val_accuracy: 0.7188
# Epoch 25/100
# 20/20 [==============================] - 15s 757ms/step - loss: 0.3597 - accuracy: 0.8906 - val_loss: 0.4977 - val_accuracy: 0.8438
# Epoch 26/100
# 20/20 [==============================] - 15s 751ms/step - loss: 0.2807 - accuracy: 0.9150 - val_loss: 0.3665 - val_accuracy: 0.8750
# Epoch 27/100
# 20/20 [==============================] - 14s 726ms/step - loss: 0.2617 - accuracy: 0.8758 - val_loss: 0.2360 - val_accuracy: 0.9250
# Epoch 28/100
# 20/20 [==============================] - 15s 755ms/step - loss: 0.2808 - accuracy: 0.9125 - val_loss: 0.3335 - val_accuracy: 0.9125
# Epoch 29/100
# 20/20 [==============================] - 15s 767ms/step - loss: 0.2543 - accuracy: 0.9219 - val_loss: 0.2272 - val_accuracy: 0.9187
# Epoch 30/100
# 20/20 [==============================] - 14s 724ms/step - loss: 0.2448 - accuracy: 0.9183 - val_loss: 0.3094 - val_accuracy: 0.8813
# Epoch 31/100
# 20/20 [==============================] - 14s 705ms/step - loss: 0.2257 - accuracy: 0.9250 - val_loss: 0.3059 - val_accuracy: 0.9250
# Epoch 32/100
# 20/20 [==============================] - 14s 720ms/step - loss: 0.1791 - accuracy: 0.9438 - val_loss: 0.1963 - val_accuracy: 0.9375
# Epoch 33/100
# 20/20 [==============================] - 14s 711ms/step - loss: 0.2317 - accuracy: 0.9219 - val_loss: 0.1686 - val_accuracy: 0.9563
# Epoch 34/100
# 20/20 [==============================] - 16s 787ms/step - loss: 0.2627 - accuracy: 0.9094 - val_loss: 0.0957 - val_accuracy: 0.9625
# Epoch 35/100
# 20/20 [==============================] - 16s 793ms/step - loss: 0.1803 - accuracy: 0.9312 - val_loss: 0.0937 - val_accuracy: 0.9688
# Epoch 36/100
# 20/20 [==============================] - 16s 785ms/step - loss: 0.2594 - accuracy: 0.9250 - val_loss: 0.1040 - val_accuracy: 0.9625
# Epoch 37/100
# 20/20 [==============================] - 15s 774ms/step - loss: 0.2266 - accuracy: 0.9062 - val_loss: 0.0941 - val_accuracy: 0.9688
# Epoch 38/100
# 20/20 [==============================] - 15s 763ms/step - loss: 0.2154 - accuracy: 0.9312 - val_loss: 0.4401 - val_accuracy: 0.8313
# Epoch 39/100
# 20/20 [==============================] - 15s 776ms/step - loss: 0.2140 - accuracy: 0.9438 - val_loss: 0.1007 - val_accuracy: 0.9688
# Epoch 40/100
# 20/20 [==============================] - 16s 788ms/step - loss: 0.2137 - accuracy: 0.9406 - val_loss: 0.1520 - val_accuracy: 0.9375
# Epoch 41/100
# 20/20 [==============================] - 15s 770ms/step - loss: 0.1691 - accuracy: 0.9438 - val_loss: 0.1678 - val_accuracy: 0.9500
# Epoch 42/100
# 20/20 [==============================] - 15s 781ms/step - loss: 0.1522 - accuracy: 0.9531 - val_loss: 0.1256 - val_accuracy: 0.9625
# Epoch 43/100
# 20/20 [==============================] - 15s 768ms/step - loss: 0.1024 - accuracy: 0.9688 - val_loss: 0.1099 - val_accuracy: 0.9750
# Epoch 44/100
# 20/20 [==============================] - 15s 775ms/step - loss: 0.1824 - accuracy: 0.9469 - val_loss: 0.0850 - val_accuracy: 0.9688
# Epoch 45/100
# 20/20 [==============================] - 15s 769ms/step - loss: 0.1840 - accuracy: 0.9344 - val_loss: 0.1718 - val_accuracy: 0.9250
# Epoch 46/100
# 20/20 [==============================] - 14s 734ms/step - loss: 0.1751 - accuracy: 0.9477 - val_loss: 0.1579 - val_accuracy: 0.9438
# Epoch 47/100
# 20/20 [==============================] - 13s 666ms/step - loss: 0.1543 - accuracy: 0.9594 - val_loss: 0.3126 - val_accuracy: 0.9125
# Epoch 48/100
# 20/20 [==============================] - 16s 799ms/step - loss: 0.2302 - accuracy: 0.9312 - val_loss: 0.1235 - val_accuracy: 0.9625
# Epoch 49/100
# 20/20 [==============================] - 15s 779ms/step - loss: 0.1275 - accuracy: 0.9625 - val_loss: 0.1061 - val_accuracy: 0.9688
# Epoch 50/100
# 20/20 [==============================] - 15s 772ms/step - loss: 0.1168 - accuracy: 0.9688 - val_loss: 0.1709 - val_accuracy: 0.9438
# Epoch 51/100
# 20/20 [==============================] - 15s 758ms/step - loss: 0.2041 - accuracy: 0.9346 - val_loss: 0.1787 - val_accuracy: 0.9375
# Epoch 52/100
# 20/20 [==============================] - 15s 773ms/step - loss: 0.2092 - accuracy: 0.9344 - val_loss: 0.1693 - val_accuracy: 0.9438
# Epoch 53/100
# 20/20 [==============================] - 15s 766ms/step - loss: 0.1717 - accuracy: 0.9344 - val_loss: 0.1496 - val_accuracy: 0.9438
# Epoch 54/100
# 20/20 [==============================] - 15s 769ms/step - loss: 0.1614 - accuracy: 0.9500 - val_loss: 0.1300 - val_accuracy: 0.9500
# Epoch 55/100
# 20/20 [==============================] - 15s 744ms/step - loss: 0.1570 - accuracy: 0.9510 - val_loss: 0.0721 - val_accuracy: 0.9812
# Epoch 56/100
# 20/20 [==============================] - 16s 793ms/step - loss: 0.1487 - accuracy: 0.9563 - val_loss: 0.1007 - val_accuracy: 0.9625
# Epoch 57/100
# 20/20 [==============================] - 16s 789ms/step - loss: 0.1870 - accuracy: 0.9406 - val_loss: 0.1116 - val_accuracy: 0.9625
# Epoch 58/100
# 20/20 [==============================] - 15s 767ms/step - loss: 0.1256 - accuracy: 0.9500 - val_loss: 0.1046 - val_accuracy: 0.9625
# Epoch 59/100
# 20/20 [==============================] - 15s 750ms/step - loss: 0.1836 - accuracy: 0.9281 - val_loss: 0.1690 - val_accuracy: 0.9500
# Epoch 60/100
# 20/20 [==============================] - 15s 763ms/step - loss: 0.1402 - accuracy: 0.9531 - val_loss: 0.2244 - val_accuracy: 0.9000
# Epoch 61/100
# 20/20 [==============================] - 15s 741ms/step - loss: 0.0827 - accuracy: 0.9739 - val_loss: 0.1774 - val_accuracy: 0.9500
# Epoch 62/100
# 20/20 [==============================] - 14s 690ms/step - loss: 0.1333 - accuracy: 0.9542 - val_loss: 0.2973 - val_accuracy: 0.9000
# Epoch 63/100
# 20/20 [==============================] - 14s 690ms/step - loss: 0.1433 - accuracy: 0.9469 - val_loss: 0.1776 - val_accuracy: 0.9563
# Epoch 64/100
# 20/20 [==============================] - 15s 777ms/step - loss: 0.1738 - accuracy: 0.9469 - val_loss: 0.1927 - val_accuracy: 0.9500
# Epoch 65/100
# 20/20 [==============================] - 15s 772ms/step - loss: 0.1162 - accuracy: 0.9563 - val_loss: 0.1305 - val_accuracy: 0.9563
# Epoch 66/100
# 20/20 [==============================] - 15s 760ms/step - loss: 0.1405 - accuracy: 0.9625 - val_loss: 0.3649 - val_accuracy: 0.8750
# Epoch 67/100
# 20/20 [==============================] - 14s 707ms/step - loss: 0.2304 - accuracy: 0.9375 - val_loss: 0.2119 - val_accuracy: 0.9375
# Epoch 68/100
# 20/20 [==============================] - 14s 723ms/step - loss: 0.1739 - accuracy: 0.9312 - val_loss: 0.1055 - val_accuracy: 0.9625
# Epoch 69/100
# 20/20 [==============================] - 15s 757ms/step - loss: 0.1088 - accuracy: 0.9575 - val_loss: 0.1270 - val_accuracy: 0.9500
# Epoch 70/100
# 20/20 [==============================] - 15s 758ms/step - loss: 0.1484 - accuracy: 0.9594 - val_loss: 0.1004 - val_accuracy: 0.9625
# Epoch 71/100
# 20/20 [==============================] - 15s 775ms/step - loss: 0.1214 - accuracy: 0.9688 - val_loss: 0.1442 - val_accuracy: 0.9563
# Epoch 72/100
# 20/20 [==============================] - 16s 784ms/step - loss: 0.1074 - accuracy: 0.9688 - val_loss: 0.0678 - val_accuracy: 0.9688
# Epoch 73/100
# 20/20 [==============================] - 16s 785ms/step - loss: 0.1307 - accuracy: 0.9594 - val_loss: 0.1025 - val_accuracy: 0.9750
# Epoch 74/100
# 20/20 [==============================] - 15s 776ms/step - loss: 0.0957 - accuracy: 0.9719 - val_loss: 0.1447 - val_accuracy: 0.9500
# Epoch 75/100
# 20/20 [==============================] - 16s 782ms/step - loss: 0.1050 - accuracy: 0.9531 - val_loss: 0.0913 - val_accuracy: 0.9688
# Epoch 76/100
# 20/20 [==============================] - 15s 753ms/step - loss: 0.1050 - accuracy: 0.9563 - val_loss: 0.2208 - val_accuracy: 0.9312
# Epoch 77/100
# 20/20 [==============================] - 16s 791ms/step - loss: 0.1249 - accuracy: 0.9594 - val_loss: 0.1000 - val_accuracy: 0.9563
# Epoch 78/100
# 20/20 [==============================] - 15s 776ms/step - loss: 0.1014 - accuracy: 0.9625 - val_loss: 0.1332 - val_accuracy: 0.9563
# Epoch 79/100
# 20/20 [==============================] - 15s 758ms/step - loss: 0.1476 - accuracy: 0.9344 - val_loss: 0.1479 - val_accuracy: 0.9500
# Epoch 80/100
# 20/20 [==============================] - 15s 771ms/step - loss: 0.0700 - accuracy: 0.9812 - val_loss: 0.1564 - val_accuracy: 0.9375
# Epoch 81/100
# 20/20 [==============================] - 15s 770ms/step - loss: 0.1455 - accuracy: 0.9500 - val_loss: 0.1122 - val_accuracy: 0.9625
# Epoch 82/100
# 20/20 [==============================] - 15s 766ms/step - loss: 0.0743 - accuracy: 0.9844 - val_loss: 0.0831 - val_accuracy: 0.9688
# Epoch 83/100
# 20/20 [==============================] - 15s 772ms/step - loss: 0.0783 - accuracy: 0.9804 - val_loss: 0.1202 - val_accuracy: 0.9563
# Epoch 84/100
# 20/20 [==============================] - 15s 745ms/step - loss: 0.0800 - accuracy: 0.9781 - val_loss: 0.1555 - val_accuracy: 0.9500
# Epoch 85/100
# 20/20 [==============================] - 15s 764ms/step - loss: 0.1134 - accuracy: 0.9625 - val_loss: 0.1502 - val_accuracy: 0.9500
# Epoch 86/100
# 20/20 [==============================] - 15s 756ms/step - loss: 0.0802 - accuracy: 0.9688 - val_loss: 0.1335 - val_accuracy: 0.9563
# Epoch 87/100
# 20/20 [==============================] - 16s 779ms/step - loss: 0.1083 - accuracy: 0.9594 - val_loss: 0.0875 - val_accuracy: 0.9750
# Epoch 88/100
# 20/20 [==============================] - 15s 757ms/step - loss: 0.1608 - accuracy: 0.9477 - val_loss: 0.3352 - val_accuracy: 0.9000
# Epoch 89/100
# 20/20 [==============================] - 15s 772ms/step - loss: 0.1056 - accuracy: 0.9688 - val_loss: 0.1059 - val_accuracy: 0.9688
# Epoch 90/100
# 20/20 [==============================] - 15s 762ms/step - loss: 0.0705 - accuracy: 0.9781 - val_loss: 0.1042 - val_accuracy: 0.9625
# Epoch 91/100
# 20/20 [==============================] - 15s 775ms/step - loss: 0.0586 - accuracy: 0.9812 - val_loss: 0.1745 - val_accuracy: 0.9438
# Epoch 92/100
# 20/20 [==============================] - 16s 792ms/step - loss: 0.0756 - accuracy: 0.9688 - val_loss: 0.1251 - val_accuracy: 0.9500
# Epoch 93/100
# 20/20 [==============================] - 16s 790ms/step - loss: 0.0779 - accuracy: 0.9844 - val_loss: 0.0541 - val_accuracy: 0.9812
# Epoch 94/100
# 20/20 [==============================] - 15s 751ms/step - loss: 0.0629 - accuracy: 0.9844 - val_loss: 0.0542 - val_accuracy: 0.9812
# Epoch 95/100
# 20/20 [==============================] - 15s 783ms/step - loss: 0.1090 - accuracy: 0.9625 - val_loss: 0.0816 - val_accuracy: 0.9875
# Epoch 96/100
# 20/20 [==============================] - 15s 761ms/step - loss: 0.0710 - accuracy: 0.9781 - val_loss: 0.0497 - val_accuracy: 0.9812
# Epoch 97/100
# 20/20 [==============================] - 15s 775ms/step - loss: 0.0709 - accuracy: 0.9719 - val_loss: 0.0438 - val_accuracy: 0.9875
# Epoch 98/100
# 20/20 [==============================] - 16s 784ms/step - loss: 0.1049 - accuracy: 0.9688 - val_loss: 0.0674 - val_accuracy: 0.9750
# Epoch 99/100
# 20/20 [==============================] - 15s 756ms/step - loss: 0.0942 - accuracy: 0.9771 - val_loss: 0.1272 - val_accuracy: 0.9563
# Epoch 100/100
# 20/20 [==============================] - 15s 759ms/step - loss: 0.0975 - accuracy: 0.9673 - val_loss: 0.1647 - val_accuracy: 0.9563

# %%
model.save('C:/Users/USER/Downloads/Bella/Augmentasi_Model.h5')

# %%
from keras.models import load_model

model = load_model('C:/Users/USER/Downloads/Bella/Augmentasi_Model.h5')

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training accuracy')
plt.plot(epochs, val_acc, 'g', label='Validation accuracy')
plt.title('Training dan Validation Accuracy')
plt.legend(loc=0)
plt.figure()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'g', label='Validation loss')
plt.title('Training dan validation loss')
plt.legend(loc=0)

plt.show()

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, confusion_matrix, classification_report
import seaborn as sns
import numpy as np

sns.set(style='whitegrid')

testLab = test_generator.classes
pred = model.predict(test_generator)
y_pred = np.argmax(pred, axis=-1)
class_names = test_generator.class_indices

print(classification_report(y_pred, testLab, target_names=class_names))
# Out:
#                  precision    recall  f1-score   support
#
# Belimbing Wuluh       0.80      1.00      0.89        28
#      Jambu Biji       0.97      0.97      0.97        35
#     Jeruk Nipis       0.97      0.89      0.93        38
#         Kemangi       1.00      0.92      0.96        38
#     Lidah Buaya       1.00      1.00      1.00        35
#          Nangka       1.00      0.95      0.97        37
#          Pandan       1.00      1.00      1.00        35
#          Pepaya       1.00      1.00      1.00        35
#         Seledri       1.00      1.00      1.00        35
#           Sirih       0.97      1.00      0.99        34
#
#        accuracy                           0.97       350
#       macro avg       0.97      0.97      0.97       350
#    weighted avg       0.98      0.97      0.97       350

# %%
Cmatrix_test = confusion_matrix(testLab, y_pred)
plt.figure(figsize=(13,10))
ax = plt.subplot()
data = np.asarray(Cmatrix_test).reshape(10,10)
sns.heatmap(data, annot=True, fmt='', ax=ax, cmap=plt.cm.Reds)
ax.set_xlabel('Predicted labels', fontsize=14)
ax.set_ylabel('True labels', fontsize=14)
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(class_names)
ax.yaxis.set_ticklabels(class_names)
plt.title('Confusion Matrix Report', fontsize=18)
plt.show()

# %%
import numpy as np
from keras.preprocessing import image
# from google.colab import files

path_test = 'C:/Users/USER/Downloads/Bella/dataset_split/test/Belimbing Wuluh/Belimbing Wuluh010.jpg'

# uploaded = files.upload()
 
# for fn in uploaded.keys():
#   path = fn
img = image.load_img(path_test, target_size=(150,150))
imgplot = plt.imshow(img)
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)

images = np.vstack([x])
classes = model.predict(images, batch_size=10)

class_list = os.listdir(train_dir)

if classes[0][0]:
    prediction="Belimbing Wuluh"
elif classes[0][1]:
    prediction="Jambu Biji"
elif classes[0][2]:
    prediction="Jeruk"
elif classes[0][3]:
    prediction="Kemangi"
elif classes[0][4]:
    prediction="Lidah Buaya"
elif classes[0][5]:
    prediction="Nangka"
elif classes[0][6]:
    prediction="Pandan"
elif classes[0][7]:
    prediction="Pepaya"
elif classes[0][8]:
    prediction="Seledri"
elif classes[0][9]:
    prediction="Sirih"
else:
    prediction="[Undefined]"
print(prediction)
# Out:
# Belimbing Wuluh
